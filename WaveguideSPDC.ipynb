# %%
import meep as mp
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Video

# %%
# Create a ring resonator with a radius of 10um

# Define materials
Si = mp.Medium(index=3.45)
SiO2 = mp.Medium(index=1.45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Create a ring resonator with a radius of 10um
#       2
#       3 # Define materials
# ----> 4 Si = mp.Medium(index=3.45)
#       5 SiO2 = mp.Medium(index=1.45)
#
# AttributeError: module 'meep' has no attribute 'Medium'

# %%
import sys
print("Python executable:", sys.executable)
print("Python version:", sys.version)
print("Python path:")
for p in sys.path[:5]:
    print(f"  {p}")
# Out:
# Python executable: /opt/miniconda3/envs/nlo/bin/python
# Python version: 3.13.12 | packaged by Anaconda, Inc. | (main, Feb 24 2026, 16:07:20) [Clang 20.1.8 ]
# Python path:
#   /opt/miniconda3/envs/nlo/lib/python313.zip
#   /opt/miniconda3/envs/nlo/lib/python3.13
#   /opt/miniconda3/envs/nlo/lib/python3.13/lib-dynload
#
#   /opt/miniconda3/envs/nlo/lib/python3.13/site-packages
